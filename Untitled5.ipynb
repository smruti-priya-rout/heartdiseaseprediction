# %%
# !pip install hvplot
# Out:
# Requirement already satisfied: hvplot in c:\users\kiit\anaconda3\lib\site-packages (0.9.2)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from hvplot) (3.3.4)
# Requirement already satisfied: colorcet>=2 in c:\users\kiit\anaconda3\lib\site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\kiit\anaconda3\lib\site-packages (from hvplot) (1.18.3)
# Requirement already satisfied: pandas in c:\users\kiit\anaconda3\lib\site-packages (from hvplot) (2.1.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\kiit\anaconda3\lib\site-packages (from hvplot) (1.26.4)
# Requirement already satisfied: packaging in c:\users\kiit\anaconda3\lib\site-packages (from hvplot) (23.1)
# Requirement already satisfied: panel>=0.11.0 in c:\users\kiit\anaconda3\lib\site-packages (from hvplot) (1.3.8)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\kiit\anaconda3\lib\site-packages (from hvplot) (2.0.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\kiit\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.3)
# Requirement already satisfied: contourpy>=1 in c:\users\kiit\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\kiit\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\kiit\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\kiit\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\kiit\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (2022.9.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\kiit\anaconda3\lib\site-packages (from colorcet>=2->hvplot) (0.5.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\kiit\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kiit\anaconda3\lib\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiit\anaconda3\lib\site-packages (from pandas->hvplot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kiit\anaconda3\lib\site-packages (from pandas->hvplot) (2023.3)
# Requirement already satisfied: markdown in c:\users\kiit\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\kiit\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\kiit\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\kiit\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in c:\users\kiit\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\kiit\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.65.0)
# Requirement already satisfied: bleach in c:\users\kiit\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\kiit\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kiit\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\kiit\anaconda3\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\kiit\anaconda3\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kiit\anaconda3\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kiit\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiit\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiit\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2024.2.2)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\kiit\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\kiit\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\kiit\anaconda3\lib\site-packages (from xgboost) (1.11.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import hvplot.pandas
import seaborn as sns
from IPython.display import display, FileLink
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e881a5ae-d8a6-4903-b753-e1d29ef29998" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"91a259a3-d60c-4742-9667-d3362c37ff47":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"c57e54716499471e8ab5c65314cbd96c","client_comm_id":"7765cbcede284a9b9cb33e4f128f8590"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"91a259a3-d60c-4742-9667-d3362c37ff47","roots":{"p1002":"e881a5ae-d8a6-4903-b753-e1d29ef29998"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#Load Dataset
df=pd.read_csv("newstatlogdata.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   70    1   4       130   322    0        2      109      0      2.4      2
# 1   67    0   3       115   564    0        2      160      0      1.6      2
# 2   57    1   2       124   261    0        0      141      0      0.3      1
# 3   64    1   4       128   263    0        0      105      1      0.2      2
# 4   74    0   2       120   269    0        2      121      1      0.2      1
#
#    ca  thal  target
# 0   3     3       1
# 1   0     7       0
# 2   0     7       1
# 3   1     7       0
# 4   1     3       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       270 non-null    int64
#  1   sex       270 non-null    int64
#  2   cp        270 non-null    int64
#  3   trestbps  270 non-null    int64
#  4   chol      270 non-null    int64
#  5   fbs       270 non-null    int64
#  6   restecg   270 non-null    int64
#  7   thalach   270 non-null    int64
#  8   exang     270 non-null    int64
#  9   oldpeak   270 non-null    float64
#  10  slope     270 non-null    int64
#  11  ca        270 non-null    int64
#  12  thal      270 non-null    int64
#  13  target    270 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 29.7 KB

# %%
df.shape
# Out:
# (270, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print("range is", df.age.max()-df.age.min())
# Out:
# range is 48

# %%
print("range is", df.fbs.max()-df.fbs.min())
# Out:
# range is 1

# %%
print("range is", df.exang.max()-df.exang.min())
# Out:
# range is 1

# %%
corr=df.corr(method='pearson')
sns.heatmap(corr,annot=True)
plt.show()

# %%
#feature Selection
corr = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.target.value_counts().hvplot.bar(
    title="Heart Disease Count", xlabel='Heart Disease', ylabel='Count',
    width=500, height=350
)
# Out:
# :Bars   [target]   (count)

# %%
#Evaluating according to sex
with_disease = df.loc[df['target']==1, 'sex'].value_counts().hvplot.bar(alpha=0.4)
without_disease = df.loc[df['target']==0, 'sex'].value_counts().hvplot.bar(alpha=0.4)

(without_disease * with_disease).opts(
    title="Heart Disease by Sex", xlabel='Sex', ylabel='Count',
    width=500, height=450, legend_cols=2, legend_position='top_right'
)
# Out:
# :Overlay
#    .Bars.Count.I  :Bars   [sex]   (count)
#    .Bars.Count.II :Bars   [sex]   (count)

# %%
with_disease = df.loc[df['target']==1, 'cp'].value_counts().hvplot.bar(alpha=0.4)
without_disease = df.loc[df['target']==0, 'cp'].value_counts().hvplot.bar(alpha=0.4)

(without_disease * with_disease).opts(
    title="Heart Disease by Chest Pain Type", xlabel='Chest Pain Type', ylabel='Count',
    width=500, height=450, legend_cols=2, legend_position='top_right'
)
# Out:
# :Overlay
#    .Bars.Count.I  :Bars   [cp]   (count)
#    .Bars.Count.II :Bars   [cp]   (count)

# %%
hwith_disease = df.loc[df['target']==1, 'fbs'].value_counts().hvplot.bar(alpha=0.4)
without_disease = df.loc[df['target']==0, 'fbs'].value_counts().hvplot.bar(alpha=0.4)

(without_disease * with_disease).opts(
    title="Heart Disease by fasting blood sugar", xlabel='fasting blood sugar > 120 mg/dl (1 = true; 0 = false)',
    ylabel='Count', width=500, height=450, legend_cols=2, legend_position='top_right'
)
# Out:
# :Overlay
#    .Bars.Count.I  :Bars   [fbs]   (count)
#    .Bars.Count.II :Bars   [cp]   (count)

# %%
with_disease = df.loc[df['target']==1, 'restecg'].value_counts().hvplot.bar(alpha=0.4)
without_disease = df.loc[df['target']==0, 'restecg'].value_counts().hvplot.bar(alpha=0.4)

(without_disease * without_disease).opts(
    title="Heart Disease by resting electrocardiographic results", xlabel='resting electrocardiographic results',
    ylabel='Count', width=500, height=450, legend_cols=2, legend_position='top_right'
)
# Out:
# :Overlay
#    .Bars.Count.I  :Bars   [restecg]   (count)
#    .Bars.Count.II :Bars   [restecg]   (count)

# %%
categorical_val = []
continous_val = []
for column in df.columns:
    if len(df[column].unique()) <= 10:
        categorical_val.append(column)
    else:
        continous_val.append(column)

# %%
categorical_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
plt.figure(figsize=(15, 15))

for i, column in enumerate(categorical_val, 1):
    plt.subplot(3, 3, i)
    df[df["target"] == 0][column].hist(bins=35, color='blue', label='Have Heart Disease = NO', alpha=0.6)
    df[df["target"] == 1][column].hist(bins=35, color='red', label='Have Heart Disease = YES', alpha=0.6)
    plt.legend()
    plt.xlabel(column)

# %%
plt.figure(figsize=(15, 15))

for i, column in enumerate(continous_val, 1):
    plt.subplot(3, 2, i)
    df[df["target"] == 0][column].hist(bins=35, color='blue', label='Have Heart Disease = NO', alpha=0.6)
    df[df["target"] == 1][column].hist(bins=35, color='red', label='Have Heart Disease = YES', alpha=0.6)
    plt.legend()
    plt.xlabel(column)

# %%
#after checking null values we'll check outliers in the dataset
plt.figure(figsize=(20,20))
ax=sns.boxplot(data=df)

# %%
 #Here we'll read and remove outlier's in the dataset using zscore matrix
from scipy import stats
z=np.abs(stats.zscore(df))
print(z)
# Out:
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    1.712094  0.689500  0.870928  0.075410  1.402212  0.417029  0.981664
# 1    1.382140  1.450327  0.183559  0.916759  6.093004  0.417029  0.981664
# 2    0.282294  0.689500  1.238045  0.411950  0.219823  0.417029  1.026285
# 3    1.052186  0.689500  0.870928  0.187590  0.258589  0.417029  1.026285
# 4    2.152032  1.450327  1.238045  0.636310  0.374890  0.417029  0.981664
# ..        ...       ...       ...       ...       ...       ...       ...
# 265  0.267629  0.689500  0.183559  2.280369  0.981951  2.397916  1.026285
# 266  1.147506  0.689500  1.238045  0.636310  0.258589  0.417029  1.026285
# 267  0.172309  1.450327  1.238045  0.485490  0.859476  0.417029  0.981664
# 268  0.282294  0.689500  0.870928  0.485490  1.117635  0.417029  1.026285
# 269  1.382140  0.689500  0.870928  1.607289  0.704409  0.417029  0.981664
#
#       thalach     exang   oldpeak     slope        ca      thal    target
# 0    1.759208  0.701222  1.181012  0.676419  2.472682  0.875706  1.118034
# 1    0.446409  0.701222  0.481153  0.676419  0.711535  1.189277  0.894427
# 2    0.375291  0.701222  0.656118  0.954234  0.711535  1.189277  1.118034
# 3    1.932198  1.426081  0.743600  0.676419  0.349871  1.189277  0.894427
# 4    1.240239  1.426081  0.743600  0.954234  0.349871  0.875706  0.894427
# ..        ...       ...       ...       ...       ...       ...       ...
# 265  0.532904  0.701222  0.481153  0.954234  0.711535  1.189277  0.894427
# 266  1.008625  0.701222  0.918565  0.954234  0.711535  1.189277  0.894427
# 267  0.143677  0.701222  0.218706  0.676419  0.711535  0.875706  0.894427
# 268  0.072560  0.701222  0.568636  0.676419  0.711535  0.673032  0.894427
# 269  1.802456  1.426081  0.393671  0.676419  2.472682  0.875706  1.118034
#
# [270 rows x 14 columns]

# %%
threshold=3
# here we'll print z whose greater than third deviation
print(np.where(z > 3)) #The first array contains the list of row numbers and second array contains respective col
# Out:
# (array([  1,   9,  52, 101, 117, 144, 156, 181, 235], dtype=int64), array([4, 4, 4, 7, 3, 3, 9, 4, 9], dtype=int64))

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3 - Q1
print(IQR)
# Out:
# age         13.0
# sex          1.0
# cp           1.0
# trestbps    20.0
# chol        67.0
# fbs          0.0
# restecg      2.0
# thalach     33.0
# exang        1.0
# oldpeak      1.6
# slope        1.0
# ca           1.0
# thal         4.0
# target       1.0
# dtype: float64

# %%
df = df[(z < 3).all(axis=1)]
df.shape #set the lower bound
# Out:
# (261, 14)

# %%
df=df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape #set the upper bound
# Out:
# (192, 14)

# %%
#To check whether the outlier's are removed
plt.figure(figsize=(20,20))
ax= sns.boxplot(data=df)

# %%
#feature Selection
plt.figure(figsize=(5,5))
d= sns.heatmap(df.corr(),cmap="coolwarm",annot=True)
# red->+ve coorelation,blue->-ve coorelation ,skyblue->0 coorelation
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
plt.savefig('d.png')

# Print a message with the download link
print('Download the heatmap image: [heatmap.png](heatmap.png)')
display(FileLink('d.png'))
# Out:
# Download the heatmap image: [heatmap.png](heatmap.png)
# C:\Users\KIIT\lastone\d.png

# %%
sns.set_context('notebook',font_scale = 2.3)
df.drop('target', axis=1).corrwith(df.target).plot(kind='bar', grid=True, figsize=(20, 10),
                                                        title="Correlation with the target feature")
plt.tight_layout()
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\KIIT\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol    fbs  \
# count  192.000000  192.000000  192.000000  192.000000  192.000000  192.0
# mean    53.177083    0.666667    3.338542  127.781250  246.166667    0.0
# std      9.158288    0.472637    0.769153   15.219307   43.948129    0.0
# min     29.000000    0.000000    2.000000   94.000000  141.000000    0.0
# 25%     45.000000    0.000000    3.000000  119.500000  212.000000    0.0
# 50%     54.000000    1.000000    4.000000  128.000000  244.500000    0.0
# 75%     60.000000    1.000000    4.000000  140.000000  274.000000    0.0
# max     76.000000    1.000000    4.000000  170.000000  360.000000    0.0
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  192.000000  192.000000  192.000000  192.000000  192.000000  192.000000
# mean     0.953125  150.552083    0.317708    0.927604    1.526042    0.473958
# std      0.998895   22.821350    0.466803    1.011876    0.578271    0.693537
# min      0.000000   88.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  136.750000    0.000000    0.000000    1.000000    0.000000
# 50%      0.000000  155.500000    0.000000    0.600000    1.000000    0.000000
# 75%      2.000000  168.000000    1.000000    1.525000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    3.600000    3.000000    2.000000
#
#              thal      target
# count  192.000000  192.000000
# mean     4.578125    0.416667
# std      1.923713    0.494296
# min      3.000000    0.000000
# 25%      3.000000    0.000000
# 50%      3.000000    0.000000
# 75%      7.000000    1.000000
# max      7.000000    1.000000

# %%
#Feature Scalling
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
dataset = pd.get_dummies(df,columns=['sex','cp','exang','ca','thal']) #creating my dummy variable
columns_to_scale= ['age','trestbps','chol','thalach','slope','restecg'] # we have taken these columns for scale down
dataset[columns_to_scale] = standardScaler.fit_transform(dataset[columns_to_scale])

# %%
dataset.head()
# Out:
#         age  trestbps      chol  fbs   restecg   thalach  oldpeak     slope  \
# 2  0.418518 -0.249100  0.338402    0 -0.956674 -0.419653      0.3 -0.912059
# 3  1.184852  0.014411  0.384029    0 -0.956674 -2.001248      0.2  0.821756
# 4  2.279613 -0.512612  0.520910    0  1.050773 -1.298317      0.2 -0.912059
# 5  1.294328 -0.512612 -1.577940    0 -0.956674 -0.463587      0.4 -0.912059
# 7  0.637471 -1.171390 -0.163497    0  1.050773 -0.375720      1.2  0.821756
#
#    target  sex_0  ...   cp_3   cp_4  exang_0  exang_1   ca_0   ca_1   ca_2  \
# 2       1  False  ...  False  False     True    False   True  False  False
# 3       0  False  ...  False   True    False     True  False   True  False
# 4       0   True  ...  False  False    False     True  False   True  False
# 5       0  False  ...  False   True     True    False   True  False  False
# 7       1  False  ...  False   True    False     True  False   True  False
#
#    thal_3  thal_6  thal_7
# 2   False   False    True
# 3   False   False    True
# 4    True   False   False
# 5   False   False    True
# 7   False   False    True
#
# [5 rows x 22 columns]

# %%
dataset.tail() #we have choosen data from bottom
# Out:
#           age  trestbps      chol  fbs   restecg   thalach  oldpeak     slope  \
# 263 -0.457291  0.146166  0.452469    0 -0.956674  0.898342      0.6 -0.912059
# 264 -0.566767 -1.171390 -0.391633    0 -0.956674  0.766542      1.0  2.555572
# 266 -1.004672 -0.512612  0.384029    0 -0.956674  0.986208      0.0 -0.912059
# 267  0.309042  0.804944  1.091250    0  1.050773  0.107545      1.3  0.821756
# 268  0.418518  0.804944 -1.235736    0 -0.956674 -0.112121      0.4  0.821756
#
#      target  sex_0  ...   cp_3   cp_4  exang_0  exang_1  ca_0   ca_1   ca_2  \
# 263       0  False  ...  False  False     True    False  True  False  False
# 264       1  False  ...  False  False     True    False  True  False  False
# 266       0  False  ...  False  False     True    False  True  False  False
# 267       0   True  ...  False  False     True    False  True  False  False
# 268       0  False  ...  False   True     True    False  True  False  False
#
#      thal_3  thal_6  thal_7
# 263    True   False   False
# 264   False   False    True
# 266   False   False    True
# 267    True   False   False
# 268   False    True   False
#
# [5 rows x 22 columns]

# %%
dataset.describe()
# Out:
#                 age      trestbps          chol    fbs       restecg  \
# count  1.920000e+02  1.920000e+02  1.920000e+02  192.0  1.920000e+02
# mean  -2.498002e-16  2.312965e-18  2.174187e-16    0.0 -5.319819e-17
# std    1.002614e+00  1.002614e+00  1.002614e+00    0.0  1.002614e+00
# min   -2.646815e+00 -2.225434e+00 -2.399229e+00    0.0 -9.566740e-01
# 25%   -8.951959e-01 -5.455505e-01 -7.794642e-01    0.0 -9.566740e-01
# 50%    9.008977e-02  1.441077e-02 -3.802264e-02    0.0 -9.566740e-01
# 75%    7.469469e-01  8.049443e-01  6.349781e-01    0.0  1.050773e+00
# max    2.498566e+00  2.781278e+00  2.596946e+00    0.0  1.050773e+00
#
#             thalach     oldpeak         slope      target
# count  1.920000e+02  192.000000  1.920000e+02  192.000000
# mean  -4.163336e-16    0.927604 -9.251859e-17    0.416667
# std    1.002614e+00    1.011876  1.002614e+00    0.494296
# min   -2.748112e+00    0.000000 -9.120592e-01    0.000000
# 25%   -6.063693e-01    0.000000 -9.120592e-01    0.000000
# 50%    2.173777e-01    0.600000 -9.120592e-01    0.000000
# 75%    7.665424e-01    1.525000  8.217563e-01    1.000000
# max    2.260270e+00    3.600000  2.555572e+00    1.000000

# %%
#visualization
sns.pairplot(df,hue="target",height=3,aspect=1);
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#feature Selection
plt.figure(figsize=(20,20))
d= sns.heatmap(df.corr(),cmap="coolwarm",annot=True)
# red->+ve coorelation,blue->-ve coorelation ,skyblue->0 coorelation
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
#model selection
y= dataset['target']
x= dataset.drop(['target'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,precision_score,recall_score,f1_score

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = 5)
knn_classifier.fit(x_train,y_train)
score = cross_val_score(knn_classifier,x_train,y_train,cv=10)
y_pred_knn=knn_classifier.predict(x_test)
accuracy = accuracy_score(y_test,y_pred_knn)
precision = precision_score(y_test, y_pred_knn)
recall = recall_score(y_test, y_pred_knn)
f1score = f1_score(y_test, y_pred_knn)
print("accuracy_score=",accuracy)
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# accuracy_score= 0.8461538461538461
# precision_score= 0.7368421052631579
# recall_score= 0.9333333333333333
# f1_score= 0.8235294117647058

# %%
score.mean()
# Out:
# 0.7775000000000001

# %%
#hyper parameter tunning
knn_classifier = KNeighborsClassifier(algorithm='auto',leaf_size=30,metric='minkowski',
                                      metric_params=None, n_jobs=1,n_neighbors=5,p=1,weights='uniform')
knn_classifier.fit(x_train,y_train)
score=cross_val_score(knn_classifier,x_train,y_train,cv=10)
y_pred_knn=knn_classifier.predict(x_test)

#hence accuracy increases after Hyper parameter tunning
accuracy = accuracy_score(y_test,y_pred_knn)
precision = precision_score(y_test, y_pred_knn)
recall = recall_score(y_test, y_pred_knn)
f1score = f1_score(y_test, y_pred_knn)
print("accuracy_score=",accuracy)
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# accuracy_score= 0.8717948717948718
# precision_score= 0.8125
# recall_score= 0.8666666666666667
# f1_score= 0.8387096774193549

# %%
score_knn=87.17
print(score_knn)
# Out:
# 87.17

# %%
score=cross_val_score(knn_classifier,x_train,y_train,cv=10)
score.mean()
# Out:
# 0.8233333333333333

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators = 20 , criterion = 'entropy', random_state=51)
rf_classifier.fit(x_train,y_train)
y_pred_rf = rf_classifier.predict(x_test)
accuracy = accuracy_score(y_test,y_pred_rf)
precision = precision_score(y_test, y_pred_rf)
recall = recall_score(y_test, y_pred_rf)
f1score = f1_score(y_test, y_pred_rf)
print("accuracy_score=",accuracy)
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# accuracy_score= 0.8974358974358975
# precision_score= 0.8235294117647058
# recall_score= 0.9333333333333333
# f1_score= 0.8749999999999999

# %%
score_rc=89.74
print(score_rc)
# Out:
# 89.74

# %%
score=cross_val_score(rf_classifier,x_train,y_train,cv=10)
score.mean()
# Out:
# 0.8370833333333334

# %% [markdown]
# XGBOOST

# %%
#XG BOOST
from xgboost import XGBClassifier
xgb_classifier = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bynode=1, colsample_bytree=0.4, gamma=0.2,
       learning_rate=0.1, max_delta_step=0, max_depth=15,
       min_child_weight=1, missing=1, n_estimators=100, n_jobs=1,
       nthread=None, objective='binary:logistic', random_state=23,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=None, subsample=1, verbosity=1)
xgb_classifier.fit(x_train, y_train)
y_pred_xgb = xgb_classifier.predict(x_test)
accuracy = accuracy_score(y_test,y_pred_xgb)
precision = precision_score(y_test, y_pred_xgb)
recall = recall_score(y_test, y_pred_xgb)
f1score = f1_score(y_test, y_pred_xgb)
print("accuracy_score=",accuracy)
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# accuracy_score= 0.8461538461538461
# precision_score= 0.7368421052631579
# recall_score= 0.9333333333333333
# f1_score= 0.8235294117647058

# %%
score_xg=84.61
print(score_xg)
# Out:
# 84.61

# %%
score=cross_val_score(xgb_classifier,x_train,y_train,cv=10)
score.mean()
# Out:
# 0.8304166666666667

# %%
#Ada Boosting With random forest
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
ada_clf = AdaBoostClassifier(RandomForestClassifier(n_estimators=100), n_estimators=100)
ada_clf.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=RandomForestClassifier(), n_estimators=100)

# %%
score=cross_val_score(xgb_classifier,x_train,y_train,cv=10)
score.mean()
# Out:
# 0.8304166666666667

# %%
#Ada Boosting With random forest
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
ada_clf = AdaBoostClassifier(RandomForestClassifier(n_estimators=100), n_estimators=100)
ada_clf.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=RandomForestClassifier(), n_estimators=100)

# %%
y_pred_adb = ada_clf.predict(x_test)
accuracy = accuracy_score(y_test,y_pred_adb)
precision = precision_score(y_test, y_pred_adb)
recall = recall_score(y_test, y_pred_adb)
f1score = f1_score(y_test, y_pred_adb)
print("accuracy_score=",accuracy)
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# accuracy_score= 0.8717948717948718
# precision_score= 0.7777777777777778
# recall_score= 0.9333333333333333
# f1_score= 0.8484848484848485

# %%
score=cross_val_score(ada_clf,x_train,y_train,cv=10)
score.mean()
# Out:
# 0.8566666666666667

# %%
score_ada=84.61
print (score_ada)
# Out:
# 84.61

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(x_train, y_train)

Y_pred_svm = sv.predict(x_test)
Y_pred_svm.shape
score_svm = round(accuracy_score(Y_pred_svm,y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
precision = precision_score(y_test, Y_pred_svm )
recall = recall_score(y_test, Y_pred_svm )
f1score = f1_score(y_test, Y_pred_svm )
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# The accuracy score achieved using Linear SVM is: 87.18 %
# precision_score= 0.7777777777777778
# recall_score= 0.9333333333333333
# f1_score= 0.8484848484848485

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()

classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = classifier.predict(x_test)
Y_pred.shape
score_dt = round(accuracy_score(Y_pred,y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
precision = precision_score(y_test, Y_pred)
recall = recall_score(y_test, Y_pred)
f1score = f1_score(y_test, Y_pred)
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# The accuracy score achieved using Decision Tree is: 79.49 %
# precision_score= 0.6666666666666666
# recall_score= 0.9333333333333333
# f1_score= 0.7777777777777778

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(x_train,y_train)

Y_pred_nb = nb.predict(x_test)

# %%
Y_pred_nb.shape
# Out:
# (39,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
precision = precision_score(y_test, Y_pred_nb)
recall = recall_score(y_test, Y_pred_nb)
f1score = f1_score(y_test, Y_pred_nb)
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# The accuracy score achieved using Naive Bayes is: 79.49 %
# precision_score= 0.6842105263157895
# recall_score= 0.8666666666666667
# f1_score= 0.7647058823529413

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Instantiate the Logistic Regression classifier
classifier = LogisticRegression()

# Train the classifier on the training data
classifier.fit(x_train, y_train)

# Make predictions on the test data
Y_pred = classifier.predict(x_test)

# Calculate the accuracy score
score_lr = round(accuracy_score(Y_pred, y_test) * 100, 2)

# Print the accuracy score achieved using Logistic Regression
print("The accuracy score achieved using Logistic Regression is: " + str(score_lr) + " %")
precision = precision_score(y_test, Y_pred )
recall = recall_score(y_test,Y_pred )
f1score = f1_score(y_test, Y_pred )
print("precision_score=",precision)
print("recall_score=",recall)
print("f1_score=",f1score)
# Out:
# The accuracy score achieved using Logistic Regression is: 84.62 %
# precision_score= 0.7368421052631579
# recall_score= 0.9333333333333333
# f1_score= 0.8235294117647058

# %%
scores = [score_knn,score_rc,score_xg,score_ada,score_svm,score_dt,score_nb,score_lr]

# %%
algorithms = ["KNN","RF","XG","ADA","SVM","DT","NB","LR"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using KNN is: 87.17 %
# The accuracy score achieved using RF is: 89.74 %
# The accuracy score achieved using XG is: 84.61 %
# The accuracy score achieved using ADA is: 84.61 %
# The accuracy score achieved using SVM is: 87.18 %
# The accuracy score achieved using DT is: 79.49 %
# The accuracy score achieved using NB is: 79.49 %
# The accuracy score achieved using LR is: 84.62 %

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'algorithms' and 'scores' are lists containing the names of algorithms and their corresponding scores
sns.set(rc={'figure.figsize':(15, 8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")
sns.barplot(x=algorithms, y=scores)
plt.show()
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
